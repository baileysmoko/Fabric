# %% [markdown]
# <a href="https://colab.research.google.com/github/baileysmoko/Fabric/blob/main/Bitmex_Funding_Rates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install BitMEX SDK if not installed
# !pip install bitmex

from bitmex import bitmex
import pandas as pd
from datetime import datetime, timedelta

# Initialize BitMEX client (public data, no keys needed)
client = bitmex(test=False)

symbol = 'XBTUSD'
chunk_size = 100  # Max rows per API call
all_data = []

# Start from the earliest possible funding rate
# BitMEX API returns most recent first, so we'll reverse with 'reverse=True'
# We'll iterate by oldest timestamp so we don't miss any
start_time = None

while True:
    # Fetch a chunk
    data_chunk = client.Funding.Funding_get(
        symbol=symbol,
        count=chunk_size,
        startTime=start_time,
        reverse=False  # Get oldest first
    ).result()[0]

    if not data_chunk:
        break  # No more data

    all_data.extend(data_chunk)

    # Update start_time to last timestamp to get the next chunk
    last_time = pd.to_datetime(data_chunk[-1]['timestamp'])
    start_time = last_time + pd.Timedelta(seconds=1)  # Avoid duplicate

    print(f"Fetched {len(data_chunk)} rows, latest timestamp in chunk: {last_time}")

# Convert to DataFrame
df = pd.DataFrame(all_data)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Save to CSV
csv_filename = 'bitmex_funding_full.csv'
df.to_csv(csv_filename, index=False)
print(f"Saved {len(df)} rows to {csv_filename}")

# Show head and tail
print("Head:")
print(df.head())
print("\nTail:")
print(df.tail())
# Out:
# Requirement already satisfied: bitmex in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: bravado in /usr/local/lib/python3.12/dist-packages (from bitmex) (12.0.1)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (6.1.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (1.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (6.0.3)
# Requirement already satisfied: requests>=2.17 in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (1.17.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (3.20.2)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (1.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from bravado->bitmex) (4.15.0)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.12/dist-packages (from bravado-core>=5.16.1->bravado->bitmex) (1.1.0)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (4.25.1)
# Requirement already satisfied: swagger-spec-validator>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from bravado-core>=5.16.1->bravado->bitmex) (3.0.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from bravado-core>=5.16.1->bravado->bitmex) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.17->bravado->bitmex) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.17->bravado->bitmex) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.17->bravado->bitmex) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.17->bravado->bitmex) (2025.11.12)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (0.30.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (3.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (0.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (25.10.0)
# Requirement already satisfied: importlib-resources>=1.3 in /usr/local/lib/python3.12/dist-packages (from swagger-spec-validator>=2.0.1->bravado-core>=5.16.1->bravado->bitmex) (6.5.2)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado->bitmex) (2025.3)
# /usr/local/lib/python3.12/dist-packages/swagger_spec_validator/validator20.py:49: SwaggerValidationWarning: Found "$ref: #/definitions/UserPreferences" with siblings that will be overwritten. See https://stackoverflow.com/a/48114924 for more information. (path #/definitions/User/properties/preferences)
#   warnings.warn(
# Fetched 100 rows, latest timestamp in chunk: 2016-06-30 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2016-08-02 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2016-09-05 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2016-10-08 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2016-11-10 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2016-12-14 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-01-16 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-02-18 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-03-24 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-04-26 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-05-29 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-07-02 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-08-04 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-09-06 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-10-10 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-11-12 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2017-12-15 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-01-18 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-02-20 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-03-25 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-04-28 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-05-31 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-07-03 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-08-06 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-09-08 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-10-11 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-11-14 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2018-12-17 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-01-19 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-02-22 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-03-27 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-04-29 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-06-02 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-07-05 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-08-07 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-09-10 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-10-13 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-11-15 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2019-12-19 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-01-21 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-02-23 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-03-28 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-04-30 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-06-02 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-07-06 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-08-08 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-09-10 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-10-14 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-11-16 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2020-12-19 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-01-22 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-02-24 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-03-29 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-05-02 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-06-04 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-07-07 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-08-10 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-09-12 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-10-15 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-11-18 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2021-12-21 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-01-23 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-02-26 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-03-31 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-05-03 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-06-06 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-07-09 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-08-11 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-09-14 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-10-17 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-11-19 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2022-12-23 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-01-25 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-02-27 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-04-02 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-05-05 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-06-07 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-07-11 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-08-13 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-09-15 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-10-19 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-11-21 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2023-12-24 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-01-27 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-02-29 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-04-02 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-05-06 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-06-08 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-07-11 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-08-14 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-09-16 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-10-19 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-11-22 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2024-12-25 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-01-27 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-03-02 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-04-04 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-05-07 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-06-10 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-07-13 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-08-15 20:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-09-18 04:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-10-21 12:00:00+00:00
# Fetched 100 rows, latest timestamp in chunk: 2025-11-23 20:00:00+00:00
# Fetched 92 rows, latest timestamp in chunk: 2025-12-24 12:00:00+00:00
# Saved 10492 rows to bitmex_funding_full.csv
# Head:
#                   timestamp  symbol           fundingInterval  fundingRate  \
# 0 2016-05-14 12:00:00+00:00  XBTUSD 2000-01-02 00:00:00+00:00     0.000690
# 1 2016-05-15 12:00:00+00:00  XBTUSD 2000-01-02 00:00:00+00:00     0.000516
# 2 2016-05-16 12:00:00+00:00  XBTUSD 2000-01-02 00:00:00+00:00     0.000451
# 3 2016-05-17 12:00:00+00:00  XBTUSD 2000-01-02 00:00:00+00:00     0.000454
# 4 2016-05-18 12:00:00+00:00  XBTUSD 2000-01-02 00:00:00+00:00     0.000443
#
#    fundingRateDaily
# 0          0.000690
# 1          0.000516
# 2          0.000451
# 3          0.000454
# 4          0.000443
#
# Tail:
#                       timestamp  symbol           fundingInterval  \
# 10487 2025-12-23 04:00:00+00:00  XBTUSD 2000-01-01 08:00:00+00:00
# 10488 2025-12-23 12:00:00+00:00  XBTUSD 2000-01-01 08:00:00+00:00
# 10489 2025-12-23 20:00:00+00:00  XBTUSD 2000-01-01 08:00:00+00:00
# 10490 2025-12-24 04:00:00+00:00  XBTUSD 2000-01-01 08:00:00+00:00
# 10491 2025-12-24 12:00:00+00:00  XBTUSD 2000-01-01 08:00:00+00:00
#
#        fundingRate  fundingRateDaily
# 10487     0.000100          0.000300
# 10488     0.000038          0.000114
# 10489     0.000044          0.000132
# 10490     0.000056          0.000168
# 10491    -0.000049         -0.000147

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Folder where you want to save all funding rates
output_folder = '/content/drive/MyDrive/top1000_tokens_20251008_154804'
os.makedirs(output_folder, exist_ok=True)  # create folder if not exists

# Full path for the CSV
csv_filename = os.path.join(output_folder, 'bitmex_funding_full.csv')

# Save DataFrame to Drive
df.to_csv(csv_filename, index=False)
print(f"✅ Saved {len(df)} rows to {csv_filename}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Saved 10492 rows to /content/drive/MyDrive/top1000_tokens_20251008_154804/bitmex_funding_full.csv
